# %%
# !pip install spotipy
# Out:
# Collecting spotipy
#   Using cached spotipy-2.25.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting redis>=3.5.3 (from spotipy)
#   Using cached redis-5.2.1-py3-none-any.whl.metadata (9.1 kB)
# Requirement already satisfied: requests>=2.25.0 in ./anaconda3/envs/newdataenv/lib/python3.8/site-packages (from spotipy) (2.32.3)
# Requirement already satisfied: urllib3>=1.26.0 in ./anaconda3/envs/newdataenv/lib/python3.8/site-packages (from spotipy) (2.2.3)
# Requirement already satisfied: async-timeout>=4.0.3 in ./anaconda3/envs/newdataenv/lib/python3.8/site-packages (from redis>=3.5.3->spotipy) (5.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./anaconda3/envs/newdataenv/lib/python3.8/site-packages (from requests>=2.25.0->spotipy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in ./anaconda3/envs/newdataenv/lib/python3.8/site-packages (from requests>=2.25.0->spotipy) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in ./anaconda3/envs/newdataenv/lib/python3.8/site-packages (from requests>=2.25.0->spotipy) (2025.1.31)
# Using cached spotipy-2.25.0-py3-none-any.whl (30 kB)
# Using cached redis-5.2.1-py3-none-any.whl (261 kB)
# Installing collected packages: redis, spotipy
# Successfully installed redis-5.2.1 spotipy-2.25.0

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
client_credentials_manager = SpotifyClientCredentials(client_id='7b2d63d5d69a4e8fa7a864be54040553', client_secret='fa86c94612f04522b43747c21cc5314d')

# %%
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
playlist_link='https://open.spotify.com/playlist/6UeSakyzhiEt4NB3UAd6NQ'

# %%
playlist_uri=playlist_link.split('/')[-1]

# %%
playlist_uri
# Out:
# '6UeSakyzhiEt4NB3UAd6NQ'

# %%
data = sp.playlist_tracks(playlist_uri)
# Out:
# Couldn't read cache at: .cache
# Couldn't write token to cache at: .cache

# %%
data['items'][0]['track']['album']['id']
# Out:
# '5HAxzyUfyay8NElNaehsNe'

# %%
data['items'][0]['track']['album']['name']
# Out:
# '4X4'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2025-01-24'

# %%
data['items'][0]['track']['album']['album_type']
# Out:
# 'single'

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/5HAxzyUfyay8NElNaehsNe'

# %%
album_list=[]
for row in data['items']:
    album_id=row['track']['album']['id']
    album_name=row['track']['album']['name']
    album_release_date=row['track']['album']['release_date']
    album_album_type=row['track']['album']['album_type']
    album_url=row['track']['album']['external_urls']['spotify']
    album_elements={'album_id':album_id,'name':album_name,'release_date':album_release_date,'type':album_album_type,'url':album_url}
    album_list.append(album_elements)

# %%
album_list
# Out:
# [{'album_id': '5HAxzyUfyay8NElNaehsNe',
#   'name': '4X4',
#   'release_date': '2025-01-24',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/5HAxzyUfyay8NElNaehsNe'},
#  {'album_id': '10FLjwfpbxLmW8c25Xyc2N',
#   'name': 'Die With A Smile',
#   'release_date': '2024-08-16',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/10FLjwfpbxLmW8c25Xyc2N'},
#  {'album_id': '2IYQwwgxgOIn7t3iF6ufFD',
#   'name': 'APT.',
#   'release_date': '2024-10-18',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/2IYQwwgxgOIn7t3iF6ufFD'},
#  {'album_id': '0hvT3yIEysuuvkK73vgdcW',
#   'name': 'GNX',
#   'release_date': '2024-11-22',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/0hvT3yIEysuuvkK73vgdcW'},
#  {'album_id': '6egBeCLeGITzGSo5VyRjwZ',
#   'name': 'A Bar Song (Tipsy)',
#   'release_date': '2024-04-12',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/6egBeCLeGITzGSo5VyRjwZ'},
#  {'album_id': '5QMiub2LonMqxB7dhtbPlX',
#   'name': 'Lose Control',
#   'release_date': '2023-06-23',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/5QMiub2LonMqxB7dhtbPlX'},
#  {'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'name': 'HIT ME HARD AND SOFT',
#   'release_date': '2024-05-17',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'},
#  {'album_id': '5K79FLRUCSysQnVESLcTdb',
#   'name': 'DeBÍ TiRAR MáS FOToS',
#   'release_date': '2025-01-05',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/5K79FLRUCSysQnVESLcTdb'},
#  {'album_id': '0hBRqPYPXhr1RkTDG3n4Mk',
#   'name': 'The Secret of Us (Deluxe)',
#   'release_date': '2024-10-18',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/0hBRqPYPXhr1RkTDG3n4Mk'},
#  {'album_id': '0TxewlKVKdpP18dGg279ep',
#   'name': 'Love Somebody',
#   'release_date': '2024-10-18',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/0TxewlKVKdpP18dGg279ep'},
#  {'album_id': '0hvT3yIEysuuvkK73vgdcW',
#   'name': 'GNX',
#   'release_date': '2024-11-22',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/0hvT3yIEysuuvkK73vgdcW'},
#  {'album_id': '1woYXxyyxTQJ0E0AhZE6mj',
#   'name': 'I Had Some Help',
#   'release_date': '2024-05-10',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/1woYXxyyxTQJ0E0AhZE6mj'},
#  {'album_id': '5quMTd5zeI9yW5UDua8wS4',
#   'name': 'Espresso',
#   'release_date': '2024-04-12',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/5quMTd5zeI9yW5UDua8wS4'},
#  {'album_id': '2QWd1BsO7J0zLwxhsKl3zh',
#   'name': 'Messy',
#   'release_date': '2024-05-30',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/2QWd1BsO7J0zLwxhsKl3zh'},
#  {'album_id': '29aSKB1qPEbN0Qf9OPSQpw',
#   'name': 'Beautiful Things',
#   'release_date': '2024-01-18',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/29aSKB1qPEbN0Qf9OPSQpw'},
#  {'album_id': '5K79FLRUCSysQnVESLcTdb',
#   'name': 'DeBÍ TiRAR MáS FOToS',
#   'release_date': '2025-01-05',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/5K79FLRUCSysQnVESLcTdb'},
#  {'album_id': '1y2OfMwyaRDmtbQNl0DnQa',
#   'name': 'Fat Juicy & Wet',
#   'release_date': '2025-01-24',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/1y2OfMwyaRDmtbQNl0DnQa'},
#  {'album_id': '2IRxVVqbSbqHJo8Zx50LYn',
#   'name': 'Timeless',
#   'release_date': '2024-09-27',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/2IRxVVqbSbqHJo8Zx50LYn'},
#  {'album_id': '3iPSVi54hsacKKl1xIR2eH',
#   'name': "Short n' Sweet",
#   'release_date': '2024-08-23',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/3iPSVi54hsacKKl1xIR2eH'},
#  {'album_id': '3VQkNrG74QPY4rHBPoyZYZ',
#   'name': 'SOS Deluxe: LANA',
#   'release_date': '2024-12-20',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/3VQkNrG74QPY4rHBPoyZYZ'},
#  {'album_id': '1fOTqAU8mRMHlmOaHMqsge',
#   'name': 'Sports car',
#   'release_date': '2025-01-24',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/1fOTqAU8mRMHlmOaHMqsge'},
#  {'album_id': '7j7HmSHKK9cp1jmPgqVNjX',
#   'name': 'Smile',
#   'release_date': '2024-12-31',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/7j7HmSHKK9cp1jmPgqVNjX'},
#  {'album_id': '0hvT3yIEysuuvkK73vgdcW',
#   'name': 'GNX',
#   'release_date': '2024-11-22',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/0hvT3yIEysuuvkK73vgdcW'},
#  {'album_id': '1KZC0cX0qq6hodR9YVgh9F',
#   'name': 'Unheard',
#   'release_date': '2024-03-22',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/1KZC0cX0qq6hodR9YVgh9F'},
#  {'album_id': '0U28P0QVB1QRxpqp5IHOlH',
#   'name': 'CHROMAKOPIA',
#   'release_date': '2024-10-28',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/0U28P0QVB1QRxpqp5IHOlH'},
#  {'album_id': '3VNxRarx9HUI5w7DHv0TBj',
#   'name': 'Stargazing',
#   'release_date': '2024-05-10',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/3VNxRarx9HUI5w7DHv0TBj'},
#  {'album_id': '5K79FLRUCSysQnVESLcTdb',
#   'name': 'DeBÍ TiRAR MáS FOToS',
#   'release_date': '2025-01-05',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/5K79FLRUCSysQnVESLcTdb'},
#  {'album_id': '62NSHNGNQC2hXZKNuvF6pi',
#   'name': 'High Road (feat. Jessie Murph)',
#   'release_date': '2024-06-07',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/62NSHNGNQC2hXZKNuvF6pi'},
#  {'album_id': '5JjnoGJyOxfSZUZtk2rRwZ',
#   'name': 'Not Like Us',
#   'release_date': '2024-05-04',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/5JjnoGJyOxfSZUZtk2rRwZ'},
#  {'album_id': '1WAjjRMfZjEXtB0lQrAw6Q',
#   'name': 'Good Luck, Babe!',
#   'release_date': '2024-04-05',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/1WAjjRMfZjEXtB0lQrAw6Q'},
#  {'album_id': '15XcLhiVMlSOipUddTNDnr',
#   'name': 'MUSE',
#   'release_date': '2024-07-19',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/15XcLhiVMlSOipUddTNDnr'},
#  {'album_id': '3VQkNrG74QPY4rHBPoyZYZ',
#   'name': 'SOS Deluxe: LANA',
#   'release_date': '2024-12-20',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/3VQkNrG74QPY4rHBPoyZYZ'},
#  {'album_id': '2PzoiaGTcK3NfnMgHFd7QC',
#   'name': 'WHATCHU KNO ABOUT ME (with Sexyy Red)',
#   'release_date': '2024-10-10',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/2PzoiaGTcK3NfnMgHFd7QC'},
#  {'album_id': '4DWrYvfGXRE8ko5ZxlIpit',
#   'name': 'Sailor Song',
#   'release_date': '2024-07-26',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/4DWrYvfGXRE8ko5ZxlIpit'},
#  {'album_id': '5K79FLRUCSysQnVESLcTdb',
#   'name': 'DeBÍ TiRAR MáS FOToS',
#   'release_date': '2025-01-05',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/5K79FLRUCSysQnVESLcTdb'},
#  {'album_id': '3iPSVi54hsacKKl1xIR2eH',
#   'name': "Short n' Sweet",
#   'release_date': '2024-08-23',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/3iPSVi54hsacKKl1xIR2eH'},
#  {'album_id': '03guxdOi12XJbnvxvxbpwG',
#   'name': 'Submarine',
#   'release_date': '2024-05-31',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/03guxdOi12XJbnvxvxbpwG'},
#  {'album_id': '2GW4VpFk9mbc6qYZ0zNuu3',
#   'name': 'Beautifully Broken',
#   'release_date': '2024-10-10',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/2GW4VpFk9mbc6qYZ0zNuu3'},
#  {'album_id': '5K79FLRUCSysQnVESLcTdb',
#   'name': 'DeBÍ TiRAR MáS FOToS',
#   'release_date': '2025-01-05',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/5K79FLRUCSysQnVESLcTdb'},
#  {'album_id': '5onhEG8O3aKdg9b4lIdkNz',
#   'name': '11:11 (Deluxe)',
#   'release_date': '2024-04-11',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/5onhEG8O3aKdg9b4lIdkNz'},
#  {'album_id': '07IZeIkEgAdjs0dSbRxn7i',
#   'name': 'I Am Not Okay',
#   'release_date': '2024-06-12',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/07IZeIkEgAdjs0dSbRxn7i'},
#  {'album_id': '2VxQFEEnhwiV5LpMuHKViR',
#   'name': 'Bad Dreams',
#   'release_date': '2024-09-13',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/2VxQFEEnhwiV5LpMuHKViR'},
#  {'album_id': '1vNUD9sUBRHFFQiwYZm232',
#   'name': 'Loco',
#   'release_date': '2024-12-20',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/1vNUD9sUBRHFFQiwYZm232'},
#  {'album_id': '2liHjGjIgWvjrfBgKGBYuF',
#   'name': 'Cold Beer & Country Music',
#   'release_date': '2024-04-05',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/2liHjGjIgWvjrfBgKGBYuF'},
#  {'album_id': '0EiI8ylL0FmWWpgHVTsZjZ',
#   'name': 'The Rise and Fall of a Midwest Princess',
#   'release_date': '2023-09-22',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/0EiI8ylL0FmWWpgHVTsZjZ'},
#  {'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'name': 'HIT ME HARD AND SOFT',
#   'release_date': '2024-05-17',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'},
#  {'album_id': '5K79FLRUCSysQnVESLcTdb',
#   'name': 'DeBÍ TiRAR MáS FOToS',
#   'release_date': '2025-01-05',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/5K79FLRUCSysQnVESLcTdb'},
#  {'album_id': '3xB16GTlwKloB2Ip22N2an',
#   'name': 'Tweaker',
#   'release_date': '2025-01-03',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/3xB16GTlwKloB2Ip22N2an'},
#  {'album_id': '5bBaoign62r1i7OV8w7mi9',
#   'name': 'Please Please Please',
#   'release_date': '2024-06-06',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/5bBaoign62r1i7OV8w7mi9'},
#  {'album_id': '3Dx1IXTwJVIMkEzVMSSSrp',
#   'name': 'Restless Mind',
#   'release_date': '2024-11-01',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/3Dx1IXTwJVIMkEzVMSSSrp'},
#  {'album_id': '5K79FLRUCSysQnVESLcTdb',
#   'name': 'DeBÍ TiRAR MáS FOToS',
#   'release_date': '2025-01-05',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/5K79FLRUCSysQnVESLcTdb'},
#  {'album_id': '0mfQ7QpjPEoeHZJZdGOsZD',
#   'name': '4×4×U',
#   'release_date': '2024-07-04',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/0mfQ7QpjPEoeHZJZdGOsZD'},
#  {'album_id': '52tXp2qZuoNlxtqD2QzoOx',
#   'name': 'How Do You Sleep At Night?',
#   'release_date': '2024-10-11',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/52tXp2qZuoNlxtqD2QzoOx'},
#  {'album_id': '0U28P0QVB1QRxpqp5IHOlH',
#   'name': 'CHROMAKOPIA',
#   'release_date': '2024-10-28',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/0U28P0QVB1QRxpqp5IHOlH'},
#  {'album_id': '60UzB8mOCMpc7xkuJE6Bwc',
#   'name': 'Alligator Bites Never Heal',
#   'release_date': '2024-08-30',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/60UzB8mOCMpc7xkuJE6Bwc'},
#  {'album_id': '5K79FLRUCSysQnVESLcTdb',
#   'name': 'DeBÍ TiRAR MáS FOToS',
#   'release_date': '2025-01-05',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/5K79FLRUCSysQnVESLcTdb'},
#  {'album_id': '7cBvtedB1E62VoOdnGx51w',
#   'name': 'Good News',
#   'release_date': '2024-11-15',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/7cBvtedB1E62VoOdnGx51w'},
#  {'album_id': '3UPTShNGcVewuV8nSxIMYY',
#   'name': 'The High Road',
#   'release_date': '2025-01-24',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/3UPTShNGcVewuV8nSxIMYY'},
#  {'album_id': '3U0pFKPURiE6x5gWFhDr8d',
#   'name': "I Ain't Sayin'",
#   'release_date': '2024-07-26',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/3U0pFKPURiE6x5gWFhDr8d'},
#  {'album_id': '52lLryGmbfkDOayypXEhhR',
#   'name': 'Think I’m In Love With You',
#   'release_date': '2023-09-08',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/52lLryGmbfkDOayypXEhhR'},
#  {'album_id': '0uuqkIU29zH9mpChddc5Tn',
#   'name': 'Qué Pasaría...',
#   'release_date': '2024-11-14',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/0uuqkIU29zH9mpChddc5Tn'},
#  {'album_id': '5K79FLRUCSysQnVESLcTdb',
#   'name': 'DeBÍ TiRAR MáS FOToS',
#   'release_date': '2025-01-05',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/5K79FLRUCSysQnVESLcTdb'},
#  {'album_id': '0VpJTeHhzQW6Z13FeBTeJD',
#   'name': 'Are You Even Real (feat. Givēon)',
#   'release_date': '2025-01-10',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/0VpJTeHhzQW6Z13FeBTeJD'},
#  {'album_id': '5K79FLRUCSysQnVESLcTdb',
#   'name': 'DeBÍ TiRAR MáS FOToS',
#   'release_date': '2025-01-05',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/5K79FLRUCSysQnVESLcTdb'},
#  {'album_id': '60cQzWfmdg4hyDXrpW6kOA',
#   'name': 'Tu Boda',
#   'release_date': '2024-09-26',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/60cQzWfmdg4hyDXrpW6kOA'},
#  {'album_id': '0XA403JTounqFh2owquBXu',
#   'name': 'Diet Pepsi',
#   'release_date': '2024-08-09',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/0XA403JTounqFh2owquBXu'},
#  {'album_id': '4BbsHmXEghoPPevQjPnHXx',
#   'name': 'F-1 Trillion',
#   'release_date': '2024-08-15',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/4BbsHmXEghoPPevQjPnHXx'},
#  {'album_id': '7l80BDHxpZwj8FXImqH8fw',
#   'name': 'Am I Okay?',
#   'release_date': '2024-07-12',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/7l80BDHxpZwj8FXImqH8fw'},
#  {'album_id': '5K79FLRUCSysQnVESLcTdb',
#   'name': 'DeBÍ TiRAR MáS FOToS',
#   'release_date': '2025-01-05',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/5K79FLRUCSysQnVESLcTdb'},
#  {'album_id': '2PluIFWJrbEgClMLJoFWzh',
#   'name': 'Heart Of A Woman',
#   'release_date': '2024-10-25',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/2PluIFWJrbEgClMLJoFWzh'},
#  {'album_id': '1pJj4lszz7C87NmizpZ144',
#   'name': 'The Largest',
#   'release_date': '2024-08-09',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/1pJj4lszz7C87NmizpZ144'},
#  {'album_id': '2Q2TRdT994vTzGE3Grmmht',
#   'name': 'Love Sick (Deluxe)',
#   'release_date': '2023-02-28',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/2Q2TRdT994vTzGE3Grmmht'},
#  {'album_id': '0atPqRDsFXU3wDVsptJVIs',
#   'name': 'Blue Jean Baby',
#   'release_date': '2025-01-27',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/0atPqRDsFXU3wDVsptJVIs'},
#  {'album_id': '5qfivA7g2aAhAIPnSb0csp',
#   'name': "It's ok I'm ok",
#   'release_date': '2024-09-12',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/5qfivA7g2aAhAIPnSb0csp'},
#  {'album_id': '01JuX8fEX5ACudymzCB3O3',
#   'name': 'Help Me',
#   'release_date': '2024-05-31',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/01JuX8fEX5ACudymzCB3O3'},
#  {'album_id': '0hvT3yIEysuuvkK73vgdcW',
#   'name': 'GNX',
#   'release_date': '2024-11-22',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/0hvT3yIEysuuvkK73vgdcW'},
#  {'album_id': '5XYdFmT54volmxN5OCI5Xy',
#   'name': 'WHAM (Extended Version)',
#   'release_date': '2025-01-10',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/5XYdFmT54volmxN5OCI5Xy'},
#  {'album_id': '5K79FLRUCSysQnVESLcTdb',
#   'name': 'DeBÍ TiRAR MáS FOToS',
#   'release_date': '2025-01-05',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/5K79FLRUCSysQnVESLcTdb'},
#  {'album_id': '3UPTShNGcVewuV8nSxIMYY',
#   'name': 'The High Road',
#   'release_date': '2025-01-24',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/3UPTShNGcVewuV8nSxIMYY'},
#  {'album_id': '5K79FLRUCSysQnVESLcTdb',
#   'name': 'DeBÍ TiRAR MáS FOToS',
#   'release_date': '2025-01-05',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/5K79FLRUCSysQnVESLcTdb'},
#  {'album_id': '4Ep5kfo5Z40qVV0vBYC8De',
#   'name': 'GBP (feat. 21 Savage)',
#   'release_date': '2025-01-16',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/4Ep5kfo5Z40qVV0vBYC8De'},
#  {'album_id': '5K79FLRUCSysQnVESLcTdb',
#   'name': 'DeBÍ TiRAR MáS FOToS',
#   'release_date': '2025-01-05',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/5K79FLRUCSysQnVESLcTdb'},
#  {'album_id': '15gT6ikjvzrlIxQ5eTpqLJ',
#   'name': 'The Days (NOTION Remix)',
#   'release_date': '2024-11-08',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/15gT6ikjvzrlIxQ5eTpqLJ'},
#  {'album_id': '1v9bkQK8p2Za27mavQqu1V',
#   'name': 'Burning Down',
#   'release_date': '2024-09-20',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/1v9bkQK8p2Za27mavQqu1V'},
#  {'album_id': '2EaHnwT7NSSG207GN94pfN',
#   'name': "weren't for the wind",
#   'release_date': '2024-10-04',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/2EaHnwT7NSSG207GN94pfN'},
#  {'album_id': '2op3VYOlPBj8PhFxLEQ0Ol',
#   'name': 'NADIE',
#   'release_date': '2024-11-21',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/2op3VYOlPBj8PhFxLEQ0Ol'},
#  {'album_id': '5cQfpT5TqmekHpZqYDcGTL',
#   'name': 'ROSONES',
#   'release_date': '2024-12-05',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/5cQfpT5TqmekHpZqYDcGTL'},
#  {'album_id': '0hvT3yIEysuuvkK73vgdcW',
#   'name': 'GNX',
#   'release_date': '2024-11-22',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/0hvT3yIEysuuvkK73vgdcW'},
#  {'album_id': '5QsVRNOKVMCeVAIUoOQJ13',
#   'name': 'TYLA +',
#   'release_date': '2024-10-11',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/5QsVRNOKVMCeVAIUoOQJ13'},
#  {'album_id': '5a450MS1eKGQQAsqgvsZ6J',
#   'name': 'Forever Young',
#   'release_date': '2024-10-18',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/5a450MS1eKGQQAsqgvsZ6J'},
#  {'album_id': '5DuihGAcuJdwyktx3EmncM',
#   'name': 'Speak for Yourself (Deluxe Version)',
#   'release_date': '2005',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/5DuihGAcuJdwyktx3EmncM'},
#  {'album_id': '5K79FLRUCSysQnVESLcTdb',
#   'name': 'DeBÍ TiRAR MáS FOToS',
#   'release_date': '2025-01-05',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/5K79FLRUCSysQnVESLcTdb'},
#  {'album_id': '389w7hzxpiOmpGEWFCNEoP',
#   'name': 'Holy Smokes',
#   'release_date': '2024-02-23',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/389w7hzxpiOmpGEWFCNEoP'},
#  {'album_id': '0K1PZ5xlzj8VctBaoAtTly',
#   'name': 'PIToRRO DE COCO',
#   'release_date': '2024-12-26',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/0K1PZ5xlzj8VctBaoAtTly'},
#  {'album_id': '3JUrJP460nFIqwjxM19slT',
#   'name': 'Wicked: The Soundtrack',
#   'release_date': '2024-11-22',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/3JUrJP460nFIqwjxM19slT'},
#  {'album_id': '0aX0UXrHG2ceYIxTQcqJdA',
#   'name': 'Cosa Nuestra',
#   'release_date': '2024-11-15',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/0aX0UXrHG2ceYIxTQcqJdA'},
#  {'album_id': '5utxE1ImIDJFXRHf137hoy',
#   'name': 'MALA MÍA',
#   'release_date': '2024-12-19',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/5utxE1ImIDJFXRHf137hoy'},
#  {'album_id': '1TGX3TzhBOkAOWyoS3TWVF',
#   'name': 'Moment of Truth',
#   'release_date': '2022-04-29',
#   'type': 'album',
#   'url': 'https://open.spotify.com/album/1TGX3TzhBOkAOWyoS3TWVF'},
#  {'album_id': '79S52DbQr4rfVJ3LUkC2P7',
#   'name': 'Boys Back Home',
#   'release_date': '2023-10-27',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/79S52DbQr4rfVJ3LUkC2P7'},
#  {'album_id': '0b64yYszabe2wxhG1PiSQo',
#   'name': 'MUTT',
#   'release_date': '2024-08-09',
#   'type': 'single',
#   'url': 'https://open.spotify.com/album/0b64yYszabe2wxhG1PiSQo'}]

# %%
data['items'][0]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Y5tJX1MQlPlqiwlOH1tJY'},
#   'href': 'https://api.spotify.com/v1/artists/0Y5tJX1MQlPlqiwlOH1tJY',
#   'id': '0Y5tJX1MQlPlqiwlOH1tJY',
#   'name': 'Travis Scott',
#   'type': 'artist',
#   'uri': 'spotify:artist:0Y5tJX1MQlPlqiwlOH1tJY'}]

# %%
artist_list=[]
for row in data['items']:
    for key, value in row.items():
        if key=='track':
            for artist in value['artists']:
                artist_dict={'artist_id':artist['id'],'artist_name':artist['name'],'external_url':artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '0Y5tJX1MQlPlqiwlOH1tJY',
#   'artist_name': 'Travis Scott',
#   'external_url': 'https://api.spotify.com/v1/artists/0Y5tJX1MQlPlqiwlOH1tJY'},
#  {'artist_id': '1HY2Jd0NmPuamShAr6KMms',
#   'artist_name': 'Lady Gaga',
#   'external_url': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms'},
#  {'artist_id': '0du5cEVh5yTK9QJze8zA0C',
#   'artist_name': 'Bruno Mars',
#   'external_url': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C'},
#  {'artist_id': '3eVa5w3URK5duf6eyVDbu9',
#   'artist_name': 'ROSÉ',
#   'external_url': 'https://api.spotify.com/v1/artists/3eVa5w3URK5duf6eyVDbu9'},
#  {'artist_id': '0du5cEVh5yTK9QJze8zA0C',
#   'artist_name': 'Bruno Mars',
#   'external_url': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C'},
#  {'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'external_url': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'artist_id': '7tYKF4w9nC0nq9CsPZTHyP',
#   'artist_name': 'SZA',
#   'external_url': 'https://api.spotify.com/v1/artists/7tYKF4w9nC0nq9CsPZTHyP'},
#  {'artist_id': '3y2cIKLjiOlp1Np37WiUdH',
#   'artist_name': 'Shaboozey',
#   'external_url': 'https://api.spotify.com/v1/artists/3y2cIKLjiOlp1Np37WiUdH'},
#  {'artist_id': '33qOK5uJ8AR2xuQQAhHump',
#   'artist_name': 'Teddy Swims',
#   'external_url': 'https://api.spotify.com/v1/artists/33qOK5uJ8AR2xuQQAhHump'},
#  {'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'artist_name': 'Billie Eilish',
#   'external_url': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'external_url': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '4tuJ0bMpJh08umKkEXKUI5',
#   'artist_name': 'Gracie Abrams',
#   'external_url': 'https://api.spotify.com/v1/artists/4tuJ0bMpJh08umKkEXKUI5'},
#  {'artist_id': '4oUHIQIBe0LHzYfvXNW4QM',
#   'artist_name': 'Morgan Wallen',
#   'external_url': 'https://api.spotify.com/v1/artists/4oUHIQIBe0LHzYfvXNW4QM'},
#  {'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'external_url': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'artist_id': '1jiZvw42D4oquLl24x2VWV',
#   'artist_name': 'Lefty Gunplay',
#   'external_url': 'https://api.spotify.com/v1/artists/1jiZvw42D4oquLl24x2VWV'},
#  {'artist_id': '246dkjvS1zLTtiykXe5h60',
#   'artist_name': 'Post Malone',
#   'external_url': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60'},
#  {'artist_id': '4oUHIQIBe0LHzYfvXNW4QM',
#   'artist_name': 'Morgan Wallen',
#   'external_url': 'https://api.spotify.com/v1/artists/4oUHIQIBe0LHzYfvXNW4QM'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_url': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '67FB4n52MgexGQIG8s0yUH',
#   'artist_name': 'Lola Young',
#   'external_url': 'https://api.spotify.com/v1/artists/67FB4n52MgexGQIG8s0yUH'},
#  {'artist_id': '22wbnEMDvgVIAGdFeek6ET',
#   'artist_name': 'Benson Boone',
#   'external_url': 'https://api.spotify.com/v1/artists/22wbnEMDvgVIAGdFeek6ET'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'external_url': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '3DbwFQlvLxRSi2uX8mf81A',
#   'artist_name': 'Sexyy Red',
#   'external_url': 'https://api.spotify.com/v1/artists/3DbwFQlvLxRSi2uX8mf81A'},
#  {'artist_id': '0du5cEVh5yTK9QJze8zA0C',
#   'artist_name': 'Bruno Mars',
#   'external_url': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C'},
#  {'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'artist_name': 'The Weeknd',
#   'external_url': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artist_id': '699OTQXzgjhIYAHMy9RyPD',
#   'artist_name': 'Playboi Carti',
#   'external_url': 'https://api.spotify.com/v1/artists/699OTQXzgjhIYAHMy9RyPD'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_url': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '7tYKF4w9nC0nq9CsPZTHyP',
#   'artist_name': 'SZA',
#   'external_url': 'https://api.spotify.com/v1/artists/7tYKF4w9nC0nq9CsPZTHyP'},
#  {'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'external_url': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'artist_id': '45dkTj5sMRSjrmBSBeiHym',
#   'artist_name': 'Tate McRae',
#   'external_url': 'https://api.spotify.com/v1/artists/45dkTj5sMRSjrmBSBeiHym'},
#  {'artist_id': '4oUHIQIBe0LHzYfvXNW4QM',
#   'artist_name': 'Morgan Wallen',
#   'external_url': 'https://api.spotify.com/v1/artists/4oUHIQIBe0LHzYfvXNW4QM'},
#  {'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'external_url': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'artist_id': '2FXC3k01G6Gw61bmprjgqS',
#   'artist_name': 'Hozier',
#   'external_url': 'https://api.spotify.com/v1/artists/2FXC3k01G6Gw61bmprjgqS'},
#  {'artist_id': '4V8LLVI7PbaPR0K2TGSxFF',
#   'artist_name': 'Tyler, The Creator',
#   'external_url': 'https://api.spotify.com/v1/artists/4V8LLVI7PbaPR0K2TGSxFF'},
#  {'artist_id': '2qoQgPAilErOKCwE2Y8wOG',
#   'artist_name': 'GloRilla',
#   'external_url': 'https://api.spotify.com/v1/artists/2qoQgPAilErOKCwE2Y8wOG'},
#  {'artist_id': '3DbwFQlvLxRSi2uX8mf81A',
#   'artist_name': 'Sexyy Red',
#   'external_url': 'https://api.spotify.com/v1/artists/3DbwFQlvLxRSi2uX8mf81A'},
#  {'artist_id': '55Aa2cqylxrFIXC767Z865',
#   'artist_name': 'Lil Wayne',
#   'external_url': 'https://api.spotify.com/v1/artists/55Aa2cqylxrFIXC767Z865'},
#  {'artist_id': '3bO19AOone0ubCsfDXDtYt',
#   'artist_name': 'Myles Smith',
#   'external_url': 'https://api.spotify.com/v1/artists/3bO19AOone0ubCsfDXDtYt'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'external_url': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '1Tie3AZgLQZqYEp8Fv4zOZ',
#   'artist_name': 'Koe Wetzel',
#   'external_url': 'https://api.spotify.com/v1/artists/1Tie3AZgLQZqYEp8Fv4zOZ'},
#  {'artist_id': '2yLzlEFtIS0Q9UkyBZdQA7',
#   'artist_name': 'Jessie Murph',
#   'external_url': 'https://api.spotify.com/v1/artists/2yLzlEFtIS0Q9UkyBZdQA7'},
#  {'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'external_url': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'artist_id': '7GlBOeep6PqTfFi59PTUUN',
#   'artist_name': 'Chappell Roan',
#   'external_url': 'https://api.spotify.com/v1/artists/7GlBOeep6PqTfFi59PTUUN'},
#  {'artist_id': '1oSPZhvZMIrWW5I41kPkkY',
#   'artist_name': 'Jimin',
#   'external_url': 'https://api.spotify.com/v1/artists/1oSPZhvZMIrWW5I41kPkkY'},
#  {'artist_id': '7tYKF4w9nC0nq9CsPZTHyP',
#   'artist_name': 'SZA',
#   'external_url': 'https://api.spotify.com/v1/artists/7tYKF4w9nC0nq9CsPZTHyP'},
#  {'artist_id': '2qoQgPAilErOKCwE2Y8wOG',
#   'artist_name': 'GloRilla',
#   'external_url': 'https://api.spotify.com/v1/artists/2qoQgPAilErOKCwE2Y8wOG'},
#  {'artist_id': '3DbwFQlvLxRSi2uX8mf81A',
#   'artist_name': 'Sexyy Red',
#   'external_url': 'https://api.spotify.com/v1/artists/3DbwFQlvLxRSi2uX8mf81A'},
#  {'artist_id': '1iCnM8foFssWlPRLfAbIwo',
#   'artist_name': 'Gigi Perez',
#   'external_url': 'https://api.spotify.com/v1/artists/1iCnM8foFssWlPRLfAbIwo'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'external_url': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_url': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '2sSGPbdZJkaSE2AbcGOACx',
#   'artist_name': 'The Marías',
#   'external_url': 'https://api.spotify.com/v1/artists/2sSGPbdZJkaSE2AbcGOACx'},
#  {'artist_id': '19k8AgwwTSxeaxkOuCQEJs',
#   'artist_name': 'Jelly Roll',
#   'external_url': 'https://api.spotify.com/v1/artists/19k8AgwwTSxeaxkOuCQEJs'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'external_url': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '7bXgB6jMjp9ATFy66eO08Z',
#   'artist_name': 'Chris Brown',
#   'external_url': 'https://api.spotify.com/v1/artists/7bXgB6jMjp9ATFy66eO08Z'},
#  {'artist_id': '19k8AgwwTSxeaxkOuCQEJs',
#   'artist_name': 'Jelly Roll',
#   'external_url': 'https://api.spotify.com/v1/artists/19k8AgwwTSxeaxkOuCQEJs'},
#  {'artist_id': '33qOK5uJ8AR2xuQQAhHump',
#   'artist_name': 'Teddy Swims',
#   'external_url': 'https://api.spotify.com/v1/artists/33qOK5uJ8AR2xuQQAhHump'},
#  {'artist_id': '6pV5zH2LzjOUHaAvENdMMa',
#   'artist_name': 'Neton Vega',
#   'external_url': 'https://api.spotify.com/v1/artists/6pV5zH2LzjOUHaAvENdMMa'},
#  {'artist_id': '4FGPzWzgjURDNT7JQ8pYgH',
#   'artist_name': 'Zach Top',
#   'external_url': 'https://api.spotify.com/v1/artists/4FGPzWzgjURDNT7JQ8pYgH'},
#  {'artist_id': '7GlBOeep6PqTfFi59PTUUN',
#   'artist_name': 'Chappell Roan',
#   'external_url': 'https://api.spotify.com/v1/artists/7GlBOeep6PqTfFi59PTUUN'},
#  {'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'artist_name': 'Billie Eilish',
#   'external_url': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'external_url': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '3E12tRURRvPfHz0hAMCFYc',
#   'artist_name': 'Omar Courtz',
#   'external_url': 'https://api.spotify.com/v1/artists/3E12tRURRvPfHz0hAMCFYc'},
#  {'artist_id': '2YRyPiW98bpkARAS4B3OQP',
#   'artist_name': 'Dei V',
#   'external_url': 'https://api.spotify.com/v1/artists/2YRyPiW98bpkARAS4B3OQP'},
#  {'artist_id': '6Pfep8fkqFHQ87DjvWu54J',
#   'artist_name': 'G3 GELO',
#   'external_url': 'https://api.spotify.com/v1/artists/6Pfep8fkqFHQ87DjvWu54J'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_url': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '08GfvCW09pv2QP4y9sle2a',
#   'artist_name': 'Sam Barber',
#   'external_url': 'https://api.spotify.com/v1/artists/08GfvCW09pv2QP4y9sle2a'},
#  {'artist_id': '5rjz63sgMaAUAyBMyCUK5D',
#   'artist_name': 'Avery Anna',
#   'external_url': 'https://api.spotify.com/v1/artists/5rjz63sgMaAUAyBMyCUK5D'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'external_url': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '6tPHARSq45lQ8BSALCfkFC',
#   'artist_name': 'Lainey Wilson',
#   'external_url': 'https://api.spotify.com/v1/artists/6tPHARSq45lQ8BSALCfkFC'},
#  {'artist_id': '6zLBxLdl60ekBLpawtT63I',
#   'artist_name': 'Cody Johnson',
#   'external_url': 'https://api.spotify.com/v1/artists/6zLBxLdl60ekBLpawtT63I'},
#  {'artist_id': '4xFUf1FHVy696Q1JQZMTRj',
#   'artist_name': 'Carrie Underwood',
#   'external_url': 'https://api.spotify.com/v1/artists/4xFUf1FHVy696Q1JQZMTRj'},
#  {'artist_id': '4V8LLVI7PbaPR0K2TGSxFF',
#   'artist_name': 'Tyler, The Creator',
#   'external_url': 'https://api.spotify.com/v1/artists/4V8LLVI7PbaPR0K2TGSxFF'},
#  {'artist_id': '67FB4n52MgexGQIG8s0yUH',
#   'artist_name': 'Lola Young',
#   'external_url': 'https://api.spotify.com/v1/artists/67FB4n52MgexGQIG8s0yUH'},
#  {'artist_id': '4E2rKHVDssGJm2SCDOMMJB',
#   'artist_name': 'Doechii',
#   'external_url': 'https://api.spotify.com/v1/artists/4E2rKHVDssGJm2SCDOMMJB'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'external_url': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '6wF1Cz760dpdbX9RJIDpQW',
#   'artist_name': 'Chuwi',
#   'external_url': 'https://api.spotify.com/v1/artists/6wF1Cz760dpdbX9RJIDpQW'},
#  {'artist_id': '3y2cIKLjiOlp1Np37WiUdH',
#   'artist_name': 'Shaboozey',
#   'external_url': 'https://api.spotify.com/v1/artists/3y2cIKLjiOlp1Np37WiUdH'},
#  {'artist_id': '3oSJ7TBVCWMDMiYjXNiCKE',
#   'artist_name': 'Kane Brown',
#   'external_url': 'https://api.spotify.com/v1/artists/3oSJ7TBVCWMDMiYjXNiCKE'},
#  {'artist_id': '19k8AgwwTSxeaxkOuCQEJs',
#   'artist_name': 'Jelly Roll',
#   'external_url': 'https://api.spotify.com/v1/artists/19k8AgwwTSxeaxkOuCQEJs'},
#  {'artist_id': '77kULmXAQ6vWer7IIHdGzI',
#   'artist_name': 'Jordan Davis',
#   'external_url': 'https://api.spotify.com/v1/artists/77kULmXAQ6vWer7IIHdGzI'},
#  {'artist_id': '4YLtscXsxbVgi031ovDDdh',
#   'artist_name': 'Chris Stapleton',
#   'external_url': 'https://api.spotify.com/v1/artists/4YLtscXsxbVgi031ovDDdh'},
#  {'artist_id': '1mcTU81TzQhprhouKaTkpq',
#   'artist_name': 'Rauw Alejandro',
#   'external_url': 'https://api.spotify.com/v1/artists/1mcTU81TzQhprhouKaTkpq'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'external_url': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'external_url': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '42LEQxfXLEuzdqorKBbUVN',
#   'artist_name': 'RaiNao',
#   'external_url': 'https://api.spotify.com/v1/artists/42LEQxfXLEuzdqorKBbUVN'},
#  {'artist_id': '33qOK5uJ8AR2xuQQAhHump',
#   'artist_name': 'Teddy Swims',
#   'external_url': 'https://api.spotify.com/v1/artists/33qOK5uJ8AR2xuQQAhHump'},
#  {'artist_id': '4fxd5Ee7UefO4CUXgwJ7IP',
#   'artist_name': 'GIVĒON',
#   'external_url': 'https://api.spotify.com/v1/artists/4fxd5Ee7UefO4CUXgwJ7IP'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'external_url': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '3l9G1G9MxH6DaRhwLklaf5',
#   'artist_name': 'Oscar Maydon',
#   'external_url': 'https://api.spotify.com/v1/artists/3l9G1G9MxH6DaRhwLklaf5'},
#  {'artist_id': '0ys2OFYzWYB5hRDLCsBqxt',
#   'artist_name': 'Fuerza Regida',
#   'external_url': 'https://api.spotify.com/v1/artists/0ys2OFYzWYB5hRDLCsBqxt'},
#  {'artist_id': '4gvjmrtzydbMpyJaXUtwvP',
#   'artist_name': 'Addison Rae',
#   'external_url': 'https://api.spotify.com/v1/artists/4gvjmrtzydbMpyJaXUtwvP'},
#  {'artist_id': '246dkjvS1zLTtiykXe5h60',
#   'artist_name': 'Post Malone',
#   'external_url': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60'},
#  {'artist_id': '718COspgdWOnwOFpJHRZHS',
#   'artist_name': 'Luke Combs',
#   'external_url': 'https://api.spotify.com/v1/artists/718COspgdWOnwOFpJHRZHS'},
#  {'artist_id': '5Ppie0uPnbnvGBYRwYmlt0',
#   'artist_name': 'Megan Moroney',
#   'external_url': 'https://api.spotify.com/v1/artists/5Ppie0uPnbnvGBYRwYmlt0'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'external_url': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '57LYzLEk2LcFghVwuWbcuS',
#   'artist_name': 'Summer Walker',
#   'external_url': 'https://api.spotify.com/v1/artists/57LYzLEk2LcFghVwuWbcuS'},
#  {'artist_id': '6qxpnaukVayrQn6ViNvu9I',
#   'artist_name': 'BigXthaPlug',
#   'external_url': 'https://api.spotify.com/v1/artists/6qxpnaukVayrQn6ViNvu9I'},
#  {'artist_id': '4Gso3d4CscCijv0lmajZWs',
#   'artist_name': 'Don Toliver',
#   'external_url': 'https://api.spotify.com/v1/artists/4Gso3d4CscCijv0lmajZWs'},
#  {'artist_id': '40ZNYROS4zLfyyBSs2PGe2',
#   'artist_name': 'Zach Bryan',
#   'external_url': 'https://api.spotify.com/v1/artists/40ZNYROS4zLfyyBSs2PGe2'},
#  {'artist_id': '45dkTj5sMRSjrmBSBeiHym',
#   'artist_name': 'Tate McRae',
#   'external_url': 'https://api.spotify.com/v1/artists/45dkTj5sMRSjrmBSBeiHym'},
#  {'artist_id': '1iwUuIOKYjV7SKIg27v4zi',
#   'artist_name': 'Real Boston Richey',
#   'external_url': 'https://api.spotify.com/v1/artists/1iwUuIOKYjV7SKIg27v4zi'},
#  {'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'external_url': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'artist_id': '6fqjJNsLs7g6F3PXy01Xnw',
#   'artist_name': 'AzChike',
#   'external_url': 'https://api.spotify.com/v1/artists/6fqjJNsLs7g6F3PXy01Xnw'},
#  {'artist_id': '5f7VJjfbwm532GiveGC0ZK',
#   'artist_name': 'Lil Baby',
#   'external_url': 'https://api.spotify.com/v1/artists/5f7VJjfbwm532GiveGC0ZK'},
#  {'artist_id': '50co4Is1HCEo8bhOyUWKpn',
#   'artist_name': 'Young Thug',
#   'external_url': 'https://api.spotify.com/v1/artists/50co4Is1HCEo8bhOyUWKpn'},
#  {'artist_id': '1RyvyyTE3xzB2ZywiAwp0i',
#   'artist_name': 'Future',
#   'external_url': 'https://api.spotify.com/v1/artists/1RyvyyTE3xzB2ZywiAwp0i'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'external_url': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '1uZVxckdGGKhFMpCnupXmP',
#   'artist_name': 'Los Pleneros de la Cresta',
#   'external_url': 'https://api.spotify.com/v1/artists/1uZVxckdGGKhFMpCnupXmP'},
#  {'artist_id': '3oSJ7TBVCWMDMiYjXNiCKE',
#   'artist_name': 'Kane Brown',
#   'external_url': 'https://api.spotify.com/v1/artists/3oSJ7TBVCWMDMiYjXNiCKE'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'external_url': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '5H4yInM5zmHqpKIoMNAx4r',
#   'artist_name': 'Central Cee',
#   'external_url': 'https://api.spotify.com/v1/artists/5H4yInM5zmHqpKIoMNAx4r'},
#  {'artist_id': '1URnnhqYAYcrqrcwql10ft',
#   'artist_name': '21 Savage',
#   'external_url': 'https://api.spotify.com/v1/artists/1URnnhqYAYcrqrcwql10ft'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'external_url': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '5bQ3wFgekuIMIcWJuxkqLK',
#   'artist_name': 'Chrystal',
#   'external_url': 'https://api.spotify.com/v1/artists/5bQ3wFgekuIMIcWJuxkqLK'},
#  {'artist_id': '1uRVM0wBdtyEuU582EeKJM',
#   'artist_name': 'NOTION',
#   'external_url': 'https://api.spotify.com/v1/artists/1uRVM0wBdtyEuU582EeKJM'},
#  {'artist_id': '0fTSzq9jAh4c36UVb4V7CB',
#   'artist_name': 'Alex Warren',
#   'external_url': 'https://api.spotify.com/v1/artists/0fTSzq9jAh4c36UVb4V7CB'},
#  {'artist_id': '6BRxQ8cD3eqnrVj6WKDok8',
#   'artist_name': 'Ella Langley',
#   'external_url': 'https://api.spotify.com/v1/artists/6BRxQ8cD3eqnrVj6WKDok8'},
#  {'artist_id': '5eumcnUkdmGvkvcsx1WFNG',
#   'artist_name': 'Tito Double P',
#   'external_url': 'https://api.spotify.com/v1/artists/5eumcnUkdmGvkvcsx1WFNG'},
#  {'artist_id': '5eumcnUkdmGvkvcsx1WFNG',
#   'artist_name': 'Tito Double P',
#   'external_url': 'https://api.spotify.com/v1/artists/5eumcnUkdmGvkvcsx1WFNG'},
#  {'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'external_url': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'artist_id': '4VHa48wXlsDA2vWfgIi7cX',
#   'artist_name': 'Dody6',
#   'external_url': 'https://api.spotify.com/v1/artists/4VHa48wXlsDA2vWfgIi7cX'},
#  {'artist_id': '3SozjO3Lat463tQICI9LcE',
#   'artist_name': 'Tyla',
#   'external_url': 'https://api.spotify.com/v1/artists/3SozjO3Lat463tQICI9LcE'},
#  {'artist_id': '1Cs0zKBU1kc0i8ypK3B9ai',
#   'artist_name': 'David Guetta',
#   'external_url': 'https://api.spotify.com/v1/artists/1Cs0zKBU1kc0i8ypK3B9ai'},
#  {'artist_id': '0xliTEbFfy5HQHvsTknTkX',
#   'artist_name': 'Alphaville',
#   'external_url': 'https://api.spotify.com/v1/artists/0xliTEbFfy5HQHvsTknTkX'},
#  {'artist_id': '4npEfmQ6YuiwW1GpUmaq3F',
#   'artist_name': 'Ava Max',
#   'external_url': 'https://api.spotify.com/v1/artists/4npEfmQ6YuiwW1GpUmaq3F'},
#  {'artist_id': '6Xb4ezwoAQC4516kI89nWz',
#   'artist_name': 'Imogen Heap',
#   'external_url': 'https://api.spotify.com/v1/artists/6Xb4ezwoAQC4516kI89nWz'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'external_url': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '3win9vGIxFfBRag9S63wwf',
#   'artist_name': 'Bailey Zimmerman',
#   'external_url': 'https://api.spotify.com/v1/artists/3win9vGIxFfBRag9S63wwf'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'external_url': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '46UMQ0cW8ToR8egkBRwAxZ',
#   'artist_name': 'Cynthia Erivo',
#   'external_url': 'https://api.spotify.com/v1/artists/46UMQ0cW8ToR8egkBRwAxZ'},
#  {'artist_id': '66CXWjxzNUsdJxJ2JdwvnR',
#   'artist_name': 'Ariana Grande',
#   'external_url': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR'},
#  {'artist_id': '1mcTU81TzQhprhouKaTkpq',
#   'artist_name': 'Rauw Alejandro',
#   'external_url': 'https://api.spotify.com/v1/artists/1mcTU81TzQhprhouKaTkpq'},
#  {'artist_id': '5lwmRuXgjX8xIwlnauTZIP',
#   'artist_name': 'Romeo Santos',
#   'external_url': 'https://api.spotify.com/v1/artists/5lwmRuXgjX8xIwlnauTZIP'},
#  {'artist_id': '0ys2OFYzWYB5hRDLCsBqxt',
#   'artist_name': 'Fuerza Regida',
#   'external_url': 'https://api.spotify.com/v1/artists/0ys2OFYzWYB5hRDLCsBqxt'},
#  {'artist_id': '6XkjpgcEsYab502Vr1bBeW',
#   'artist_name': 'Grupo Frontera',
#   'external_url': 'https://api.spotify.com/v1/artists/6XkjpgcEsYab502Vr1bBeW'},
#  {'artist_id': '6IKlXZEFOvk9itrP1s0knJ',
#   'artist_name': 'The Red Clay Strays',
#   'external_url': 'https://api.spotify.com/v1/artists/6IKlXZEFOvk9itrP1s0knJ'},
#  {'artist_id': '0ZZLr8EH3aNFzYpXtaTIax',
#   'artist_name': 'Dylan Marlowe',
#   'external_url': 'https://api.spotify.com/v1/artists/0ZZLr8EH3aNFzYpXtaTIax'},
#  {'artist_id': '78YqeIji3mgAS2K1Maca6x',
#   'artist_name': 'Dylan Scott',
#   'external_url': 'https://api.spotify.com/v1/artists/78YqeIji3mgAS2K1Maca6x'},
#  {'artist_id': '0nnBZ8FXWjG9wZgM2cpfeb',
#   'artist_name': 'Leon Thomas',
#   'external_url': 'https://api.spotify.com/v1/artists/0nnBZ8FXWjG9wZgM2cpfeb'}]

# %%
album_df=pd.DataFrame.from_dict(album_list)

# %%
album_df
# Out:
#                   album_id                name release_date    type  \
# 0   5HAxzyUfyay8NElNaehsNe                 4X4   2025-01-24  single
# 1   10FLjwfpbxLmW8c25Xyc2N    Die With A Smile   2024-08-16  single
# 2   2IYQwwgxgOIn7t3iF6ufFD                APT.   2024-10-18  single
# 3   0hvT3yIEysuuvkK73vgdcW                 GNX   2024-11-22   album
# 4   6egBeCLeGITzGSo5VyRjwZ  A Bar Song (Tipsy)   2024-04-12  single
# ..                     ...                 ...          ...     ...
# 95  0aX0UXrHG2ceYIxTQcqJdA        Cosa Nuestra   2024-11-15   album
# 96  5utxE1ImIDJFXRHf137hoy            MALA MÍA   2024-12-19  single
# 97  1TGX3TzhBOkAOWyoS3TWVF     Moment of Truth   2022-04-29   album
# 98  79S52DbQr4rfVJ3LUkC2P7      Boys Back Home   2023-10-27  single
# 99  0b64yYszabe2wxhG1PiSQo                MUTT   2024-08-09  single
#
#                                                   url
# 0   https://open.spotify.com/album/5HAxzyUfyay8NEl...
# 1   https://open.spotify.com/album/10FLjwfpbxLmW8c...
# 2   https://open.spotify.com/album/2IYQwwgxgOIn7t3...
# 3   https://open.spotify.com/album/0hvT3yIEysuuvkK...
# 4   https://open.spotify.com/album/6egBeCLeGITzGSo...
# ..                                                ...
# 95  https://open.spotify.com/album/0aX0UXrHG2ceYIx...
# 96  https://open.spotify.com/album/5utxE1ImIDJFXRH...
# 97  https://open.spotify.com/album/1TGX3TzhBOkAOWy...
# 98  https://open.spotify.com/album/79S52DbQr4rfVJ3...
# 99  https://open.spotify.com/album/0b64yYszabe2wxh...
#
# [100 rows x 5 columns]

# %%
artist_df=pd.DataFrame.from_dict(artist_list)

# %%
artist_df
# Out:
#                   artist_id          artist_name  \
# 0    0Y5tJX1MQlPlqiwlOH1tJY         Travis Scott
# 1    1HY2Jd0NmPuamShAr6KMms            Lady Gaga
# 2    0du5cEVh5yTK9QJze8zA0C           Bruno Mars
# 3    3eVa5w3URK5duf6eyVDbu9                 ROSÉ
# 4    0du5cEVh5yTK9QJze8zA0C           Bruno Mars
# ..                      ...                  ...
# 133  6XkjpgcEsYab502Vr1bBeW       Grupo Frontera
# 134  6IKlXZEFOvk9itrP1s0knJ  The Red Clay Strays
# 135  0ZZLr8EH3aNFzYpXtaTIax        Dylan Marlowe
# 136  78YqeIji3mgAS2K1Maca6x          Dylan Scott
# 137  0nnBZ8FXWjG9wZgM2cpfeb          Leon Thomas
#
#                                           external_url
# 0    https://api.spotify.com/v1/artists/0Y5tJX1MQlP...
# 1    https://api.spotify.com/v1/artists/1HY2Jd0NmPu...
# 2    https://api.spotify.com/v1/artists/0du5cEVh5yT...
# 3    https://api.spotify.com/v1/artists/3eVa5w3URK5...
# 4    https://api.spotify.com/v1/artists/0du5cEVh5yT...
# ..                                                 ...
# 133  https://api.spotify.com/v1/artists/6XkjpgcEsYa...
# 134  https://api.spotify.com/v1/artists/6IKlXZEFOvk...
# 135  https://api.spotify.com/v1/artists/0ZZLr8EH3aN...
# 136  https://api.spotify.com/v1/artists/78YqeIji3mg...
# 137  https://api.spotify.com/v1/artists/0nnBZ8FXWjG...
#
# [138 rows x 3 columns]

# %%
artist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138 entries, 0 to 137
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   artist_id     138 non-null    object
#  1   artist_name   138 non-null    object
#  2   external_url  138 non-null    object
# dtypes: object(3)
# memory usage: 3.4+ KB

# %%
artist_df.head()
# Out:
#                 artist_id   artist_name  \
# 0  0Y5tJX1MQlPlqiwlOH1tJY  Travis Scott
# 1  1HY2Jd0NmPuamShAr6KMms     Lady Gaga
# 2  0du5cEVh5yTK9QJze8zA0C    Bruno Mars
# 3  3eVa5w3URK5duf6eyVDbu9          ROSÉ
# 4  0du5cEVh5yTK9QJze8zA0C    Bruno Mars
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/0Y5tJX1MQlP...
# 1  https://api.spotify.com/v1/artists/1HY2Jd0NmPu...
# 2  https://api.spotify.com/v1/artists/0du5cEVh5yT...
# 3  https://api.spotify.com/v1/artists/3eVa5w3URK5...
# 4  https://api.spotify.com/v1/artists/0du5cEVh5yT...

# %%
artist_df=artist_df.drop_duplicates(subset=['artist_id'])

# %%
artist_df
# Out:
#                   artist_id          artist_name  \
# 0    0Y5tJX1MQlPlqiwlOH1tJY         Travis Scott
# 1    1HY2Jd0NmPuamShAr6KMms            Lady Gaga
# 2    0du5cEVh5yTK9QJze8zA0C           Bruno Mars
# 3    3eVa5w3URK5duf6eyVDbu9                 ROSÉ
# 5    2YZyLoL8N0Wb9xBt1NhZWg       Kendrick Lamar
# ..                      ...                  ...
# 133  6XkjpgcEsYab502Vr1bBeW       Grupo Frontera
# 134  6IKlXZEFOvk9itrP1s0knJ  The Red Clay Strays
# 135  0ZZLr8EH3aNFzYpXtaTIax        Dylan Marlowe
# 136  78YqeIji3mgAS2K1Maca6x          Dylan Scott
# 137  0nnBZ8FXWjG9wZgM2cpfeb          Leon Thomas
#
#                                           external_url
# 0    https://api.spotify.com/v1/artists/0Y5tJX1MQlP...
# 1    https://api.spotify.com/v1/artists/1HY2Jd0NmPu...
# 2    https://api.spotify.com/v1/artists/0du5cEVh5yT...
# 3    https://api.spotify.com/v1/artists/3eVa5w3URK5...
# 5    https://api.spotify.com/v1/artists/2YZyLoL8N0W...
# ..                                                 ...
# 133  https://api.spotify.com/v1/artists/6XkjpgcEsYa...
# 134  https://api.spotify.com/v1/artists/6IKlXZEFOvk...
# 135  https://api.spotify.com/v1/artists/0ZZLr8EH3aN...
# 136  https://api.spotify.com/v1/artists/78YqeIji3mg...
# 137  https://api.spotify.com/v1/artists/0nnBZ8FXWjG...
#
# [89 rows x 3 columns]

# %%
album_df=album_df.drop_duplicates(subset=['album_id'])

# %%
album_df.head()
# Out:
#                  album_id                name release_date    type  \
# 0  5HAxzyUfyay8NElNaehsNe                 4X4   2025-01-24  single
# 1  10FLjwfpbxLmW8c25Xyc2N    Die With A Smile   2024-08-16  single
# 2  2IYQwwgxgOIn7t3iF6ufFD                APT.   2024-10-18  single
# 3  0hvT3yIEysuuvkK73vgdcW                 GNX   2024-11-22   album
# 4  6egBeCLeGITzGSo5VyRjwZ  A Bar Song (Tipsy)   2024-04-12  single
#
#                                                  url
# 0  https://open.spotify.com/album/5HAxzyUfyay8NEl...
# 1  https://open.spotify.com/album/10FLjwfpbxLmW8c...
# 2  https://open.spotify.com/album/2IYQwwgxgOIn7t3...
# 3  https://open.spotify.com/album/0hvT3yIEysuuvkK...
# 4  https://open.spotify.com/album/6egBeCLeGITzGSo...

# %%
import sys
print(sys.version)
# Out:
# 3.8.18 | packaged by conda-forge | (default, Oct 10 2023, 15:46:56)
# [Clang 16.0.6 ]
